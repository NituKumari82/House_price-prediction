# %%
import pandas as pd   
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error,r2_score
from xgboost import XGBRegressor
import joblib

# %%
df=pd.read_csv("dataset (1).csv")
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
missing_values=df.isnull().sum().sort_values(ascending=False)
missing_values
# Out:
# PoolQC           1453
# MiscFeature      1406
# Alley            1369
# Fence            1179
# MasVnrType        872
#                  ...
# MoSold              0
# YrSold              0
# SaleType            0
# SaleCondition       0
# SalePrice           0
# Length: 81, dtype: int64

# %%
m_value=missing_values[missing_values>500]
plt.figure(figsize=(10,8))
sns.barplot(x=m_value,y=m_value.index,palette='viridis')
plt.title("missing_values By Featurs")
plt.xlabel("count of missing valus")
plt.ylabel("Features")
plt.show()
# Out:
# C:\Users\nituk\AppData\Local\Temp\ipykernel_15704\1006184736.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=m_value,y=m_value.index,palette='viridis')

# %%
df = df.drop(columns=['Id','PoolQC','FireplaceQu','Fence','Alley','MiscFeature','MasVnrType'])

# %%
df
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0             60       RL         65.0     8450   Pave      Reg         Lvl
# 1             20       RL         80.0     9600   Pave      Reg         Lvl
# 2             60       RL         68.0    11250   Pave      IR1         Lvl
# 3             70       RL         60.0     9550   Pave      IR1         Lvl
# 4             60       RL         84.0    14260   Pave      IR1         Lvl
# ...          ...      ...          ...      ...    ...      ...         ...
# 1455          60       RL         62.0     7917   Pave      Reg         Lvl
# 1456          20       RL         85.0    13175   Pave      Reg         Lvl
# 1457          70       RL         66.0     9042   Pave      Reg         Lvl
# 1458          20       RL         68.0     9717   Pave      Reg         Lvl
# 1459          20       RL         75.0     9937   Pave      Reg         Lvl
#
# ...

# %%
df.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrArea', 'ExterQual',
#        'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure',
#        'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF',
#        'TotalBsmtSF', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical',
#        '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath',
#        'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr',
#        'KitchenQual', 'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
c_column=df.select_dtypes(include=['object','category']).columns
print("categorical Column :")
print(c_column)
# Out:
# categorical Column :
# Index(['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional',
#        'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
label_encoder=LabelEncoder()
c_column=['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
       'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
       'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
       'Exterior2nd', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
       'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating',
       'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional',
       'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive',
       'SaleType', 'SaleCondition']
for col in c_column :
  df[col]=label_encoder.fit_transform(df[col])

# %%
df
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0             60         3         65.0     8450       1         3
# 1             20         3         80.0     9600       1         3
# 2             60         3         68.0    11250       1         0
# 3             70         3         60.0     9550       1         0
# 4             60         3         84.0    14260       1         0
# ...          ...       ...          ...      ...     ...       ...
# 1455          60         3         62.0     7917       1         3
# 1456          20         3         85.0    13175       1         3
# 1457          70         3         66.0     9042       1         3
# 1458          20         3         68.0     9717       1         3
# 1459          20         3         75.0     9937       1         3
#
#       LandContour  Utilities  LotConfig  LandSlope  ...  EnclosedPorch  \
# 0               3          0          4          0  ...              0
# ...

# %%
corr_matrix=df.corr()
corr_with_price=corr_matrix['SalePrice'].sort_values(ascending=False)
print("correlation feature",corr_with_price.head(20))
# Out:
# correlation feature SalePrice       1.000000
# OverallQual     0.790982
# GrLivArea       0.708624
# GarageCars      0.640409
# GarageArea      0.623431
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# FullBath        0.560664
# TotRmsAbvGrd    0.533723
# YearBuilt       0.522897
# YearRemodAdd    0.507101
# GarageYrBlt     0.486362
# MasVnrArea      0.477493
# Fireplaces      0.466929
# BsmtFinSF1      0.386420
# Foundation      0.382479
# LotFrontage     0.351799
# WoodDeckSF      0.324413
# 2ndFlrSF        0.319334
# OpenPorchSF     0.315856
# Name: SalePrice, dtype: float64

# %%
# Assuming 'corr_with_price' has already been calculated correctly
c_feature = corr_with_price[corr_with_price > 0.25].index

# CORRECTED LINE: Filter the DataFrame to keep only those columns

# %%
df=df[c_feature]
df
# Out:
#       SalePrice  OverallQual  GrLivArea  GarageCars  GarageArea  TotalBsmtSF  \
# 0        208500            7       1710           2         548          856
# 1        181500            6       1262           2         460         1262
# 2        223500            7       1786           2         608          920
# 3        140000            7       1717           3         642          756
# 4        250000            8       2198           3         836         1145
# ...         ...          ...        ...         ...         ...          ...
# 1455     175000            6       1647           2         460          953
# 1456     210000            6       2073           2         500         1542
# 1457     266500            7       2340           1         252         1152
# 1458     142125            5       1078           1         240         1078
# 1459     147500            5       1256           1         276         1256
#
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df[corr_with_price[corr_with_price>0.25].index].corr(),fmt='.2f',cmap='Reds')
plt.title("correlation with heat_map")
plt.show()

# %%
df=df.drop(columns=['GarageCars', 'GarageYrBlt', 'TotRmsAbvGrd', 'Foundation', '2ndFlrSF', 'HalfBath', 'TotalBsmtSF'])

# %%
df
# Out:
#       SalePrice  OverallQual  GrLivArea  GarageArea  1stFlrSF  FullBath  \
# 0        208500            7       1710         548       856         2
# 1        181500            6       1262         460      1262         2
# 2        223500            7       1786         608       920         2
# 3        140000            7       1717         642       961         1
# 4        250000            8       2198         836      1145         2
# ...         ...          ...        ...         ...       ...       ...
# 1455     175000            6       1647         460       953         2
# 1456     210000            6       2073         500      2073         2
# 1457     266500            7       2340         252      1188         2
# 1458     142125            5       1078         240      1078         1
# 1459     147500            5       1256         276      1256         1
#
#       YearBuilt  YearRemodAdd  MasVnrArea  Fireplaces  BsmtFinSF1  \
# ...

# %%
df.sample(5)
# Out:
#       SalePrice  OverallQual  GrLivArea  GarageArea  1stFlrSF  FullBath  \
# 1262     161500            4       1788         304      1104         1
# 1229     127000            5       1507         404      1507         2
# 1063     110500            6       1103         440      1103         1
# 1180     250000            7       2514         693      1298         2
# 1159     185000            6       1876         540       943         2
#
#       YearBuilt  YearRemodAdd  MasVnrArea  Fireplaces  BsmtFinSF1  \
# 1262       1957          1989         0.0           2           0
# 1229       1960          1960         0.0           0         666
# 1063       1925          1980         0.0           1         397
# 1180       1990          1991         0.0           0        1216
# 1159       1974          1974       270.0           1         442
#
#       LotFrontage  WoodDeckSF  OpenPorchSF  LotArea  CentralAir
# 1262          NaN         120            0    11250           1
# ...

# %%
df.isnull().sum()
# Out:
# SalePrice         0
# OverallQual       0
# GrLivArea         0
# GarageArea        0
# 1stFlrSF          0
# FullBath          0
# YearBuilt         0
# YearRemodAdd      0
# MasVnrArea        8
# Fireplaces        0
# BsmtFinSF1        0
# LotFrontage     259
# WoodDeckSF        0
# OpenPorchSF       0
# LotArea           0
# CentralAir        0
# dtype: int64

# %%
df['LotFrontage']=df['LotFrontage'].fillna(df['LotFrontage'].mean())

# %%
df.isnull().sum()
# Out:
# SalePrice       0
# OverallQual     0
# GrLivArea       0
# GarageArea      0
# 1stFlrSF        0
# FullBath        0
# YearBuilt       0
# YearRemodAdd    0
# MasVnrArea      8
# Fireplaces      0
# BsmtFinSF1      0
# LotFrontage     0
# WoodDeckSF      0
# OpenPorchSF     0
# LotArea         0
# CentralAir      0
# dtype: int64

# %%
x=df.drop('SalePrice',axis=1)
y=df['SalePrice']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x
# Out:
#       OverallQual  GrLivArea  GarageArea  1stFlrSF  FullBath  YearBuilt  \
# 0               7       1710         548       856         2       2003
# 1               6       1262         460      1262         2       1976
# 2               7       1786         608       920         2       2001
# 3               7       1717         642       961         1       1915
# 4               8       2198         836      1145         2       2000
# ...           ...        ...         ...       ...       ...        ...
# 1455            6       1647         460       953         2       1999
# 1456            6       2073         500      2073         2       1978
# 1457            7       2340         252      1188         2       1941
# 1458            5       1078         240      1078         1       1950
# 1459            5       1256         276      1256         1       1965
#
#       YearRemodAdd  MasVnrArea  Fireplaces  BsmtFinSF1  LotFrontage  \
# ...

# %%
y
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
model= XGBRegressor(
objective='reg:squarederror',

learning_rate = 0.01,

max_depth = 6,

n_estimators = 1000,

subsample = 0.65,

random_state = 42
)
model.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.01, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=1000,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred= model.predict(x_test)


mae = mean_absolute_error(y_test, predictions)
print("Mean absolute error:",mae)


r2 = r2_score(y_test, predictions)
print("r2 score:",r2)
# Out:
# Mean absolute error: 18283.67578125
# r2 score: 0.8966776132583618

# %%
joblib.dump(model,'xgb_model.jb')
# Out:
# ['xgb_model.jb']
